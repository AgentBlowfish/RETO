# %%
from dash import Dash, html, dcc, Input, Output  # pip install dash
import dash_bootstrap_components as dbc
#from vega_datasets import data             # pip install vega-datasets
import pandas as pd
import numpy as np

import altair as alt                        # pip install altair

import matplotlib.pyplot as plt             # pip install matplotlib
import mpld3                                # pip install mpld3

from bokeh.plotting import figure           # pip install Bokeh
from bokeh.resources import CDN
from bokeh.embed import file_html
from bokeh.models import ColumnDataSource

# %%
# bring data into app
casetas = pd.read_excel('Casetas TDR.xlsx')
tlvia = pd.read_excel('Compilado televía 2.xlsx')

# %%
tlvia
# Out:
#      Concesionaria               Fecha  #Unidad           TAG  \
# 0          VIAPASS 2024-01-30 03:42:00     1725  OHLM01380783
# 1          VIAPASS 2024-01-27 23:52:00     1725  OHLM01380783
# 2          VIAPASS 2024-01-25 06:21:31     1725  OHLM01380783
# 3          VIAPASS 2024-01-23 02:45:29     1725  OHLM01380783
# 4          VIAPASS 2024-01-22 07:09:23     1725  OHLM01380783
# ...            ...                 ...      ...           ...
# 2107       CEPSICE 2024-01-03 02:06:00     1753  OHLM02010066
# 2108       CEPSICE 2024-01-01 22:57:00     1753  OHLM02010066
# 2109       CEPSICE 2024-01-01 21:35:00     1753  OHLM02010066
# 2110       CEPSICE 2024-01-01 20:00:00     1753  OHLM02010066
# 2111       CEPSICE 2024-01-01 19:04:00     1753  OHLM02010066
#
#                                               Entrada  \
# 0     TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 08B
# 1     TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 01A
# 2     TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 08B
# 3     TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 01A
# 4     TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 08B
# ...                                               ...
# 2107            ENT. RAUDALES - CTRA OCOZOCOAUTLA 182
# 2108            ENT. RAUDALES - CTRA OCOZOCOAUTLA 182
# 2109                 ENT. RAUDALES-CTRA MALPASITO 181
# 2110       ENT. NUEVO SACRIFICIO-CTRA LAS CHOAPAS 179
# 2111   CARDENAS - AGUA DULCE - CTRA S. MAGALLANES 176
#
#                                                Salida  Importe
# 0     TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 08B      265
# 1     TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 01A      265
# 2     TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 08B      265
# 3     TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 01A      265
# 4     TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 08B      265
# ...                                               ...      ...
# 2107            ENT. RAUDALES - CTRA OCOZOCOAUTLA 182      312
# 2108            ENT. RAUDALES - CTRA OCOZOCOAUTLA 182      312
# 2109                 ENT. RAUDALES-CTRA MALPASITO 181      312
# 2110       ENT. NUEVO SACRIFICIO-CTRA LAS CHOAPAS 179      312
# 2111   CARDENAS - AGUA DULCE - CTRA S. MAGALLANES 176      309
#
# [2112 rows x 7 columns]

# %%
#Generamos variables para las tajetas de televia y casetas pagadas  (TDR)

#Contavilizamos el numero de filas del dataset tlvia
caspag = tlvia.Entrada.count()

#Sumamos el importe de las casetas pagadas (TDR)
casimpTDR = casetas['Costo Caseta'].sum()

#Sumamos el importe de las casetas pagadas (Televia)
casimpTV = tlvia['Importe'].sum()

# %%
#generamos el layout de la app para 3 tarjetas de informacion ordenadas horizontalmente
app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

app.layout = html.Div([
    dbc.Row([
        dbc.Col([
            dbc.Card([
                dbc.CardBody([
                    html.H4(" # Casetas Pagadas (Televia)", className="card-title"),
                    html.H2(f"{caspag}",
                            className="card-text"),
                ])
            ])
        ]),

        dbc.Col([
            dbc.Card([
                dbc.CardBody([
                    html.H4("Importe Caseta Pagadas (TDR)", className="card-title"),
                    html.H2(f"${casimpTDR:,.2f}",
                            className="card-text"),
                ])
            ])
        ]),
        dbc.Col([
            dbc.Card([
                dbc.CardBody([
                    html.H4("Importe Caseta Pagadas (Televia)", className="card-title"),
                    html.H2(f"${casimpTV:,.2f}",
                            className="card-text"),
                ])
            ])
        ])
    ])
])

if __name__ == '__main__': 
    app.run_server(debug=True, port = 8051)
#fer gei
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px
import pandas as pd

# Preparar los datos
df = pd.DataFrame({
    "Fruit": ["Apples", "Oranges", "Bananas", "Apples", "Oranges", "Bananas"],
    "Amount": [4, 1, 2, 2, 4, 5],
    "City": ["SF", "SF", "SF", "Montreal", "Montreal", "Montreal"]
})

# Inicializar la aplicación
app = dash.Dash(__name__)

# Definir el layout
app.layout = html.Div([
    dcc.Dropdown(
        id="dropdown",
        options=[
            {"label": col, "value": col} for col in df.columns
        ],
        value="Fruit"
    ),
    dcc.Graph(id="bar-chart")
])

# Definir la callback
@app.callback(
    Output("bar-chart", "figure"), 
    [Input("dropdown", "value")]
)
def update_bar_chart(column):
    fig = px.bar(df, x="City", y=column, color="City", barmode="group")
    return fig

# Correr la aplicación
if __name__ == "__main__":
    app.run_server(debug=True, port = 8052)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8052/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

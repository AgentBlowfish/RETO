# %%
from dash import Dash, html, dcc, Input, Output  # pip install dash
import dash_bootstrap_components as dbc
#from vega_datasets import data             # pip install vega-datasets
import pandas as pd
import numpy as np

import altair as alt                        # pip install altair

import matplotlib.pyplot as plt             # pip install matplotlib
import mpld3                                # pip install mpld3

from bokeh.plotting import figure           # pip install Bokeh
from bokeh.resources import CDN
from bokeh.embed import file_html
from bokeh.models import ColumnDataSource

# %%
# bring data into app
casetas = pd.read_excel('Casetas TDR.xlsx')
tlvia = pd.read_excel('Compilado televía 2.xlsx')

# %%
tlvia
# Out:
#              Concesionaria               Fecha  #Unidad  \
# TAG
# OHLM01380783       VIAPASS 2024-01-30 03:42:00     1725
# OHLM01380783       VIAPASS 2024-01-27 23:52:00     1725
# OHLM01380783       VIAPASS 2024-01-25 06:21:31     1725
# OHLM01380783       VIAPASS 2024-01-23 02:45:29     1725
# OHLM01380783       VIAPASS 2024-01-22 07:09:23     1725
# ...                    ...                 ...      ...
# OHLM02010066       CEPSICE 2024-01-03 02:06:00     1753
# OHLM02010066       CEPSICE 2024-01-01 22:57:00     1753
# OHLM02010066       CEPSICE 2024-01-01 21:35:00     1753
# OHLM02010066       CEPSICE 2024-01-01 20:00:00     1753
# OHLM02010066       CEPSICE 2024-01-01 19:04:00     1753
#
#                                                       Entrada  \
# TAG
# OHLM01380783  TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 08B
# OHLM01380783  TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 01A
# OHLM01380783  TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 08B
# OHLM01380783  TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 01A
# OHLM01380783  TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 08B
# ...                                                       ...
# OHLM02010066            ENT. RAUDALES - CTRA OCOZOCOAUTLA 182
# OHLM02010066            ENT. RAUDALES - CTRA OCOZOCOAUTLA 182
# OHLM02010066                 ENT. RAUDALES-CTRA MALPASITO 181
# OHLM02010066       ENT. NUEVO SACRIFICIO-CTRA LAS CHOAPAS 179
# OHLM02010066   CARDENAS - AGUA DULCE - CTRA S. MAGALLANES 176
#
#                                                        Salida  Importe
# TAG
# OHLM01380783  TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 08B      265
# OHLM01380783  TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 01A      265
# OHLM01380783  TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 08B      265
# OHLM01380783  TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 01A      265
# OHLM01380783  TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 08B      265
# ...                                                       ...      ...
# OHLM02010066            ENT. RAUDALES - CTRA OCOZOCOAUTLA 182      312
# OHLM02010066            ENT. RAUDALES - CTRA OCOZOCOAUTLA 182      312
# OHLM02010066                 ENT. RAUDALES-CTRA MALPASITO 181      312
# OHLM02010066       ENT. NUEVO SACRIFICIO-CTRA LAS CHOAPAS 179      312
# OHLM02010066   CARDENAS - AGUA DULCE - CTRA S. MAGALLANES 176      309
#
# [2112 rows x 6 columns]

# %%
#Generamos variables para las tajetas de televia y casetas pagadas  (TDR)

#Contavilizamos el numero de filas del dataset tlvia
caspag = tlvia.Entrada.count()

#Sumamos el importe de las casetas pagadas (TDR)
casimpTDR = casetas['Costo Caseta'].sum()

#Sumamos el importe de las casetas pagadas (Televia)
casimpTV = tlvia['Importe'].sum()

# %%
#generamos el layout de la app para 3 tarjetas de informacion ordenadas horizontalmente
app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

app.layout = html.Div([
    dbc.Row([
        dbc.Col([
            dbc.Card([
                dbc.CardBody([
                    html.H4(" # Casetas Pagadas (Televia)", className="card-title"),
                    html.H2(f"{caspag}",
                            className="card-text"),
                ])
            ])
        ]),

        dbc.Col([
            dbc.Card([
                dbc.CardBody([
                    html.H4("Importe Caseta Pagadas (TDR)", className="card-title"),
                    html.H2(f"${casimpTDR:,.2f}",
                            className="card-text"),
                ])
            ])
        ]),
        dbc.Col([
            dbc.Card([
                dbc.CardBody([
                    html.H4("Importe Caseta Pagadas (Televia)", className="card-title"),
                    html.H2(f"${casimpTV:,.2f}",
                            className="card-text"),
                ])
            ])
        ])
    ])
])

if __name__ == '__main__': 
    app.run_server(debug=True, port = 8051)
#fer gei
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
